# %% [markdown]
# <a href="https://colab.research.google.com/github/VaishnaviBairagoni/AIML-Lab/blob/main/Assignment-1(new).ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import numpy as np
list=[3,2,4]
array1= np.array(list)
array1
print(type(list))
print(type(array1))
list2=[6,7,8]
array2=np.array(list2)
array2
print("array2 multiplied by array1:",array1,array2)
print("array2 divided by array1:",array2/array1)
print("array2 raised to the power of array1:",array2**array1)
print(f"{array2} raised to the power of {array1}:,{array2**array1}")
import numpy as np
#sine function
print("sine:" ,np.sin(array1))
#logrithm
print("Natural logarithm: ",np.log(array1))
print("Base-10 logarithm: ",np.log10(array1))
print("Base-2 logarithm: ",np.log2(array1))
#exponential
print("exponential: ",np.exp(array1))
print("Adding two numpy arrays{array1} and {array2} together:",array1+array2)
print("Adding two numpy arrays {array1} and {array2} together : {array1+array2}")
people = ['ann','brandon','chen','david','emily','farook',
          'gagan','hamish','imran','julio','katherine','lily']
age = [21,12,32,45,37,18,28,52,5,40,48,15]
weight = [55,35,77,68,70,60,72,69,18,65,82,48]
height = [160,135,170,165,173,168,175,159,105,171,155,158]
import matplotlib.pyplot as plt
plt.scatter(weight, height)
plt.title("Relationship between weight and height  of patients")
plt.ylabel("height in meters ")
plt.xlabel("weight of patients in kgs")
plt.show()
plt.figure(figsize=(12,4))
plt.title("people is weight in kgs",fontsize=16,
          fontstyle='italic')
#main plot function 'bar'
plt.bar(x=people,height=weight,width=0.6,
        color='orange',edgecolor='k',alpha=0.6)
plt.xlabel("people",fontsize=15)
#plt.xticks(fontsize=14,rotation=30)
#plt.yticks(fontsize=14)
plt.ylabel("weight (in kgs)",fontsize=15)
plt.show()
import numpy as np
plt.figure(figsize=(7,5))
# main plot function 'hist'
plt.hist(weight,color='red',edgecolor='k',alpha=0.75,bins=5)

plt.title("histogram of patient weight",fontsize=18)
plt.xlabel("weight in kgs",fontsize=15)
#plt.xticks(fontsize=15)
#plt.yticks(fontsize=15)
plt.show()
# Out:
# <class 'list'>
# <class 'numpy.ndarray'>
# array2 multiplied by array1: [3 2 4] [6 7 8]
# array2 divided by array1: [2.  3.5 2. ]
# array2 raised to the power of array1: [ 216   49 4096]
# [6 7 8] raised to the power of [3 2 4]:,[ 216   49 4096]
# sine: [ 0.14112001  0.90929743 -0.7568025 ]
# Natural logarithm:  [1.09861229 0.69314718 1.38629436]
# Base-10 logarithm:  [0.47712125 0.30103    0.60205999]
# Base-2 logarithm:  [1.5849625 1.        2.       ]
# exponential:  [20.08553692  7.3890561  54.59815003]
# Adding two numpy arrays{array1} and {array2} together: [ 9  9 12]
# Adding two numpy arrays {array1} and {array2} together : {array1+array2}
